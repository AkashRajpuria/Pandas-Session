# %%
import pandas as pd
df = pd.read_excel("Indori.xlsx")

# %%
df.head()
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
# 2  Lunch/Dinner        Andhra Styke Chicken
# 3  Lunch/Dinner        Andhra Chilli Paneer
# 4  Lunch/Dinner                     Avakkai
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2  https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# 3  https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...      Vegetarian
# 4  https://www.sanjeevkapoor.com/Recipe/Avakkai-S...      Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
# 2  Andhra Pradesh           21-25 minutes
# 3  Andhra Pradesh           16-20 minutes
# 4  Andhra Pradesh                 1-2days
#
# ...

# %%
l = [1,2,3]

# %%
l[0]
# Out:
# 1

# %%
#iloc or loc - indexing

# %%
df.head()
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
# 2  Lunch/Dinner        Andhra Styke Chicken
# 3  Lunch/Dinner        Andhra Chilli Paneer
# 4  Lunch/Dinner                     Avakkai
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2  https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# 3  https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...      Vegetarian
# 4  https://www.sanjeevkapoor.com/Recipe/Avakkai-S...      Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
# 2  Andhra Pradesh           21-25 minutes
# 3  Andhra Pradesh           16-20 minutes
# 4  Andhra Pradesh                 1-2days
#
# ...

# %% [markdown]
# # **iloc**

# %%
#iloc
#df.iloc[R,C] 2 rows and 4 column
df.iloc[0:1,0:3]
# Out:
#            Meal         Recipe Name  \
# 0  Lunch/Dinner  Imli Chawal Recipe
#
#                                                Links
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...

# %%
df.iloc[0:2,0:4]
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian

# %%
df.iloc[:2,:4]
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian

# %%
#23 rows se 30
#
df.iloc[23:31,3:6]
# Out:
#               Type         Cuisine Time to Prepare(in min)
# 23      Vegetarian  Andhra Pradesh           26-30 minutes
# 24      Vegetarian  Andhra Pradesh           31-40 minutes
# 25      Vegetarian  Andhra Pradesh           11-15 minutes
# 26      Vegetarian  Andhra Pradesh           16-20 minutes
# 27      Vegetarian  Andhra Pradesh           16-20 minutes
# 28      Vegetarian  Andhra Pradesh           26-30 minutes
# 29      Vegetarian  Andhra Pradesh           27-30 minutes
# 30  Non Vegetarian  Andhra Pradesh           41-50 minutes

# %%
df.iloc[[0,5,9],[1,3]]
# Out:
#                Recipe Name            Type
# 0       Imli Chawal Recipe      Vegetarian
# 5  Tamarind Leaves Chutney      Vegetarian
# 9    Andhra Chilli Chicken  Non-Vegetarian

# %% [markdown]
# # Loc

# %%
df.head(3)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
# 2  Lunch/Dinner        Andhra Styke Chicken
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2  https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
# 2  Andhra Pradesh           21-25 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
# 2  [Chicken cut into 8 pieces on the bone 750 gra...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# ...

# %%
df.loc[2:30,['Cuisine',"Recipe Name"]]
# Out:
#            Cuisine                    Recipe Name
# 2   Andhra Pradesh           Andhra Styke Chicken
# 3   Andhra Pradesh           Andhra Chilli Paneer
# 4   Andhra Pradesh                        Avakkai
# 5   Andhra Pradesh        Tamarind Leaves Chutney
# 6   Andhra Pradesh      Andhra Style Mutton Curry
# 7   Andhra Pradesh          Andhra Chicken Pickle
# 8   Andhra Pradesh            Gutti Vankaya Koora
# 9   Andhra Pradesh          Andhra Chilli Chicken
# 10  Andhra Pradesh           Andhra Style Chicken
# 11  Andhra Pradesh              Sugarcane Panakam
# 12  Andhra Pradesh                     Egg Pulusu
# 13  Andhra Pradesh  Andhra Drumstick Curry Recipe
# 14  Andhra Pradesh   Andhra Mashed Brinjal Recipe
# 15  Andhra Pradesh           Turai Chutney Recipe
# 16  Andhra Pradesh    Rayalseema Pesarettu Recipe
# 17  Andhra Pradesh        Vankaya Perugesi Recipe
# 18  Andhra Pradesh         Vankaya Poornam Recipe
# 19  Andhra Pradesh          Baingan Saaswe Recipe
# ...

# %%
df.loc[25:40,["Recipe Name","Type","Time to Prepare(in min)"]]
# Out:
#                      Recipe Name            Type Time to Prepare(in min)
# 25             Mor Koottu Recipe      Vegetarian           11-15 minutes
# 26  Pumpkin More Kozhambu Recipe      Vegetarian           16-20 minutes
# 27         Kadugu Maangai Recipe      Vegetarian           16-20 minutes
# 28        Coconut Khara Kozhambu      Vegetarian           26-30 minutes
# 29       Chenai Podutuval Recipe      Vegetarian           27-30 minutes
# 30     Guntur Chilli Kodi Recipe  Non Vegetarian           41-50 minutes
# 31    Karela Andhra Style Recipe      Vegetarian           21-25 minutes
# 32                Ariselu Recipe      Vegetarian           26-30 minutes
# 33      Kakkarkai Pullusu Recipe      Vegetarian           31-40 minutes
# 34         Andhra Chilli Chicken  Non-Vegetarian           32-40 minutes
# 35                Avakkai Recipe      Vegetarian                  3 days
# 36              Thakkali Pachadi      Vegetarian           26-30 minutes
# ...

# %%
df['Type']=="Vegetarian"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 5182     True
# 5183     True
# 5184     True
# 5185     True
# 5186     True
# Name: Type, Length: 5187, dtype: bool

# %%
df.loc[df['Type']=="Vegetarian",['Recipe Name','Type','Time to Prepare(in min)','Instructions']]
# Out:
#                   Recipe Name        Type Time to Prepare(in min)  \
# 0          Imli Chawal Recipe  Vegetarian           21-25 minutes
# 3        Andhra Chilli Paneer  Vegetarian           16-20 minutes
# 4                     Avakkai  Vegetarian                 1-2days
# 5     Tamarind Leaves Chutney  Vegetarian           16-20 minutes
# 8         Gutti Vankaya Koora  Vegetarian           26-30 minutes
# ...                       ...         ...                     ...
# 5182                Medu Vada  Vegetarian           21-25 minutes
# 5183                  Sambhar  Vegetarian           26-30 minutes
# 5184                    Rasam  Vegetarian           21-25 minutes
# 5185             Idli Sambhar  Vegetarian           21-25 minutes
# 5186                Veg Kurma  Vegetarian           16-20 minutes
#
#                                            Instructions
# 0     1. Heat oil in a non-stick pan, add mustard se...
# 3     1. Put the soaked dried red chillies, garlic, ...
# ...

# %%
df.loc[
    (df['Type']=="Vegetarian") &
     (df['Recipe Name'].str.contains("paneer",case=False))





,['Recipe Name','Type','Time to Prepare(in min)','Instructions']]
# Out:
#                        Recipe Name        Type Time to Prepare(in min)  \
# 3             Andhra Chilli Paneer  Vegetarian           16-20 minutes
# 46            Paneer Rezala Recipe  Vegetarian           16-20 minutes
# 290          Paneer Nazakat Recipe  Vegetarian           26-30 minutes
# 321   Paneer Piste Ka Salan Recipe  Vegetarian           16-20 minutes
# 349    Paneer Kofta Mirch Do Pyaza  Vegetarian           21-25 minutes
# ...                            ...         ...                     ...
# 5127                  Paneer Curry  Vegetarian           21-25 minutes
# 5161                   Aloo Paneer  Vegetarian           16-20 minutes
# 5165                 Paneer Kulcha  Vegetarian            11-15 minute
# 5171                    Paneer Fry  Vegetarian           31-40 minutes
# 5177             Paneer Kali Mirch  Vegetarian           31-40 minutes
#
#                                            Instructions
# 3     1. Put the soaked dried red chillies, garlic, ...
# ...
