# %% [markdown]
# INDoRI comprises recipes from various Indian regions, detailing ingredients and their relationships. This dataset is ideal for demonstrating pandas functions due to its structured format and cultural relevance

# %%
import pandas as pd
data = pd.read_excel("Indori.xlsx")

# %%
data.head()
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
# 2  Lunch/Dinner        Andhra Styke Chicken
# 3  Lunch/Dinner        Andhra Chilli Paneer
# 4  Lunch/Dinner                     Avakkai
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2  https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# 3  https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...      Vegetarian
# 4  https://www.sanjeevkapoor.com/Recipe/Avakkai-S...      Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
# 2  Andhra Pradesh           21-25 minutes
# 3  Andhra Pradesh           16-20 minutes
# 4  Andhra Pradesh                 1-2days
#
# ...

# %%
data.shape
# Out:
# (5187, 10)

# %%
data['Ingredients'][0]
# Out:
# '[Tamarind (imli) pulp 4 tablespoons,\nCooked rice (cooked with salt and turmeric powder) 3 cups,\nOil 2 tablespoons,\nMustard seeds 1/2 teaspoon,\nSplit Bengal gram 1 teaspoon,\nSplit skinless black gram 1 teaspoon,\nAsafoetida a large pi,\nCurry leaves 10-15,\nGreen chillies finely chopped 2,\nDried red chillies broken into large pieces 2,\nRoasted peanuts crushed 1/2 cup,\nRoasted sesame seeds 1 teaspoon,\nSalt to taste]'

# %%
data['New Ingredients'][0]
# Out:
# 'Tamarind (imli) pulp  4 tablespoons\nCooked rice (cooked with salt and turmeric powder) 3 cups\nOil  2  tablespoons\nMustard seeds  1/2 teaspoon\nSplit Bengal gram  1 teaspoon\nSplit skinless black gram  1 teaspoon\nAsafoetida  a large pi\nCurry leaves  10-15\nGreen chillies finely chopped 2\nDried red chillies broken into large pieces 2\nRoasted peanuts crushed 1/2 cup\nRoasted sesame seeds  1 teaspoon\nSalt   to taste\n'

# %% [markdown]
# # Value Counts: df['col'].value_counts()

# %%
# Value Counts: Analyze the most common cuisines in the dataset
# Purpose: Counts unique values in a column.
# Example: Identify the most common ingredients across all recipes.
# Industry Use Case: In marketing, determine the most popular products sold.
cuisine_counts = data['Cuisine'].value_counts()
cuisine_counts
# Out:
# Cuisine
# Maharashtrian     677
# Uttar Pradesh     502
# Indian            488
# East              446
# Punjabi           435
# Tamil Nadu        414
# Gujarati          293
# Kerala            279
# Karnataka         268
# Hyderabadi        256
# Andhra Pradesh    198
# Bengali           192
# Rajasthani        166
# Madhya Pradesh    160
# Bihari            148
# Kashmiri          133
# Sindhi             94
# Mumbai             20
# Marwari            18
# Name: count, dtype: int64

# %%
data['Type'].value_counts()
# Out:
# Type
# Vegetarian        4385
# Non-Vegetarian     597
# Non Vegetarian     205
# Name: count, dtype: int64

# %% [markdown]
# # Unique Values: df['col'].unique()

# %%
data[['Type',"Cuisine"]].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-8285441c9901> in <cell line: 1>()
# ----> 1 data[['Type',"Cuisine"]].unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
data['Type'].unique()
# Out:
# array(['Vegetarian', 'Non-Vegetarian', 'Non Vegetarian'], dtype=object)

# %%
# Unique Values: List all unique meal types
unique_meals = data['Meal'].unique()
# Purpose: Returns unique values in a column.
# Example: List all unique cuisines represented in the dataset.
# Industry Use Case: In customer data, identify all unique customer segments.
unique_meals
# Out:
# array(['Lunch/Dinner', 'Chutney Recipes', 'Pickle', 'Drink',
#        'Breakfast/Snacks', 'Deserts', 'Bread Recipes', 'Raita', nan,
#        'Soup'], dtype=object)

# %%
data['Meal'].value_counts()
# Out:
# Meal
# Lunch/Dinner        2838
# Breakfast/Snacks    1156
# Deserts              646
# Bread Recipes        248
# Chutney Recipes      136
# Drink                 79
# Pickle                50
# Raita                 23
# Soup                   1
# Name: count, dtype: int64

# %% [markdown]
# # Renaming Rows and Columns: df.rename()

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                      New Ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# ...

# %%
# Renaming Columns: Rename 'Time to Prepare(in min)' for simplicity
data.rename(columns={'Time to Prepare(in min)': 'Prep_Time',
                     "New Ingredients" : "clean_ingredients"})
# Purpose: Renames columns or index labels.
# Example: Rename the 'dish_name' column to 'recipe_name'.
# Industry Use Case: Standardizing column names after data ingestion.
# Out:
#                   Meal                 Recipe Name  \
# 0         Lunch/Dinner          Imli Chawal Recipe
# 1         Lunch/Dinner  Andhra Mutton Curry Recipe
# 2         Lunch/Dinner        Andhra Styke Chicken
# 3         Lunch/Dinner        Andhra Chilli Paneer
# 4         Lunch/Dinner                     Avakkai
# ...                ...                         ...
# 5182  Breakfast/Snacks                   Medu Vada
# 5183  Breakfast/Snacks                     Sambhar
# 5184  Breakfast/Snacks                       Rasam
# 5185  Breakfast/Snacks                Idli Sambhar
# 5186  Breakfast/Snacks                   Veg Kurma
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine Time to Prepare(in min)  \
# 0  Andhra Pradesh           21-25 minutes
# 1  Andhra Pradesh           31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                      New Ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# ...

# %%
# data = data.rename(columns={'Time to Prepare(in min)': 'Prep_Time',
#                      "New Ingredients" : "clean_ingredients"})

data.rename(columns={'Time to Prepare(in min)': 'Prep_Time',
                     "New Ingredients" : "clean_ingredients"},inplace=True) #permant change

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                    clean_ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# 1  Mutton   cubed 500 grams\nOnion\nSalt   to tas...
#
# ...

# %%
data.columns
# Out:
# Index(['Meal', 'Recipe Name', 'Links', 'Type', 'Cuisine', 'Prep_Time',
#        'Ingredients', 'Instructions', 'clean_ingredients', 'Image Link'],
#       dtype='object')

# %%
data.columns = ['Meal', 'Recipe Name', 'Links', 'Type', 'Cuisine', 'Prep_Time',
       'Ingredients', 'Instructions', 'clean_ingredients', 'Image_url']

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                    clean_ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# 1  Mutton   cubed 500 grams\nOnion\nSalt   to tas...
#
# ...

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of                   Meal                 Recipe Name  \
# 0         Lunch/Dinner          Imli Chawal Recipe
# 1         Lunch/Dinner  Andhra Mutton Curry Recipe
# 2         Lunch/Dinner        Andhra Styke Chicken
# 3         Lunch/Dinner        Andhra Chilli Paneer
# 4         Lunch/Dinner                     Avakkai
# ...                ...                         ...
# 5182  Breakfast/Snacks                   Medu Vada
# 5183  Breakfast/Snacks                     Sambhar
# 5184  Breakfast/Snacks                       Rasam
# 5185  Breakfast/Snacks                Idli Sambhar
# 5186  Breakfast/Snacks                   Veg Kurma
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
data.isna
# Out:
# <bound method DataFrame.isna of                   Meal                 Recipe Name  \
# 0         Lunch/Dinner          Imli Chawal Recipe
# 1         Lunch/Dinner  Andhra Mutton Curry Recipe
# 2         Lunch/Dinner        Andhra Styke Chicken
# 3         Lunch/Dinner        Andhra Chilli Paneer
# 4         Lunch/Dinner                     Avakkai
# ...                ...                         ...
# 5182  Breakfast/Snacks                   Medu Vada
# 5183  Breakfast/Snacks                     Sambhar
# 5184  Breakfast/Snacks                       Rasam
# 5185  Breakfast/Snacks                Idli Sambhar
# 5186  Breakfast/Snacks                   Veg Kurma
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
data.isnull()
# Out:
#        Meal  Recipe Name  Links   Type  Cuisine  Prep_Time  Ingredients  \
# 0     False        False  False  False    False      False        False
# 1     False        False  False  False    False      False        False
# 2     False        False  False  False    False      False        False
# 3     False        False  False  False    False      False        False
# 4     False        False  False  False    False      False        False
# ...     ...          ...    ...    ...      ...        ...          ...
# 5182  False        False  False  False    False      False        False
# 5183  False        False  False  False    False      False        False
# 5184  False        False  False  False    False      False        False
# 5185  False        False  False  False    False      False        False
# 5186  False        False  False  False    False      False        False
#
#       Instructions  clean_ingredients  Image_url
# 0            False              False      False
# ...

# %%
False + True + True
# Out:
# 2

# %%
data.isnull().sum()
# Out:
# Meal                   10
# Recipe Name             0
# Links                   0
# Type                    0
# Cuisine                 0
# Prep_Time               0
# Ingredients             0
# Instructions           30
# clean_ingredients      15
# Image_url            2447
# dtype: int64

# %% [markdown]
# # Dropping Rows/Columns: df.drop()

# %%
data.dropna()
# Out:
#                   Meal                 Recipe Name  \
# 0         Lunch/Dinner          Imli Chawal Recipe
# 1         Lunch/Dinner  Andhra Mutton Curry Recipe
# 2         Lunch/Dinner        Andhra Styke Chicken
# 3         Lunch/Dinner        Andhra Chilli Paneer
# 4         Lunch/Dinner                     Avakkai
# ...                ...                         ...
# 5181  Breakfast/Snacks                  Lemon Rice
# 5182  Breakfast/Snacks                   Medu Vada
# 5184  Breakfast/Snacks                       Rasam
# 5185  Breakfast/Snacks                Idli Sambhar
# 5186  Breakfast/Snacks                   Veg Kurma
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
data
# Out:
#                   Meal                 Recipe Name  \
# 0         Lunch/Dinner          Imli Chawal Recipe
# 1         Lunch/Dinner  Andhra Mutton Curry Recipe
# 2         Lunch/Dinner        Andhra Styke Chicken
# 3         Lunch/Dinner        Andhra Chilli Paneer
# 4         Lunch/Dinner                     Avakkai
# ...                ...                         ...
# 5182  Breakfast/Snacks                   Medu Vada
# 5183  Breakfast/Snacks                     Sambhar
# 5184  Breakfast/Snacks                       Rasam
# 5185  Breakfast/Snacks                Idli Sambhar
# 5186  Breakfast/Snacks                   Veg Kurma
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
data.dropna(subset=['Instructions'],inplace=True)

# %%
# Dropping Rows with missing 'Instructions'
data_cleaned = data.dropna(subset=['Instructions'])
# Purpose: Removes specified labels from rows or columns.
# Example: Remove rows with missing ingredient information.
# Industry Use Case: Eliminating irrelevant features in a dataset.

# %%
data_cleaned.loc[5183]
# Out:
# Meal                                                  Breakfast/Snacks
# Recipe Name                                                    Sambhar
# Links                https://www.indianhealthyrecipes.com/andhra-sa...
# Type                                                        Vegetarian
# Cuisine                                                     Hyderabadi
# Prep_Time                                                26-30 minutes
# Ingredients          ['toor dal pigeon', 'dal', 'tamarind tamarind'...
# Instructions         1. Cook tuvar daal with haldi and water and ke...
# clean_ingredients    2 Cup Tuvar Dal\n1/2 tsp Haldi (Turmeric)\n3 R...
# Image_url                                                          NaN
# Name: 5183, dtype: object

# %%
data_cleaned.shape
# Out:
# (5157, 10)

# %% [markdown]
# # Setting and Resetting Index: set_index(), reset_index()

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                    clean_ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# 1  Mutton   cubed 500 grams\nOnion\nSalt   to tas...
#
# ...

# %%
# Set 'Recipe Name' as index
data_cleaned.set_index('Recipe Name', inplace=True)
# Setting and Resetting Index: set_index(), reset_index()

# Purpose: Sets or resets the DataFrame index.
# Example: Set 'recipe_id' as the index for easier data manipulation.
# Industry Use Case: Using a unique identifier as the index for quick lookups.
data_cleaned
# Out:
#                                         Meal  \
# Recipe Name
# Imli Chawal Recipe              Lunch/Dinner
# Andhra Mutton Curry Recipe      Lunch/Dinner
# Andhra Styke Chicken            Lunch/Dinner
# Andhra Chilli Paneer            Lunch/Dinner
# Avakkai                         Lunch/Dinner
# ...                                      ...
# Medu Vada                   Breakfast/Snacks
# Sambhar                     Breakfast/Snacks
# Rasam                       Breakfast/Snacks
# Idli Sambhar                Breakfast/Snacks
# Veg Kurma                   Breakfast/Snacks
#
#                                                                         Links  \
# Recipe Name
# Imli Chawal Recipe          https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...
# Andhra Mutton Curry Recipe  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...
# Andhra Styke Chicken        https://www.sanjeevkapoor.com/Recipe/Andhra-St...
# Andhra Chilli Paneer        https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...
# ...

# %%
data_cleaned.loc['Idli Sambhar']
# Out:
#                           Meal  \
# Recipe Name
# Idli Sambhar  Breakfast/Snacks
# Idli Sambhar  Breakfast/Snacks
#
#                                                           Links        Type  \
# Recipe Name
# Idli Sambhar  https://www.indianhealthyrecipes.com/idli-samb...  Vegetarian
# Idli Sambhar  https://www.indianhealthyrecipes.com/idli-samb...  Vegetarian
#
#                  Cuisine      Prep_Time  \
# Recipe Name
# Idli Sambhar  Hyderabadi  21-25 minutes
# Idli Sambhar  Hyderabadi  21-25 minutes
#
#                                                     Ingredients  \
# Recipe Name
# Idli Sambhar  ['dal', 'dal', 'tamarind', 'Salt', 'shallots o...
# Idli Sambhar  ['dal', 'dal', 'tamarind', 'Salt', 'shallots o...
#
#                                                    Instructions  \
# Recipe Name
# Idli Sambhar  1. Rinse and pressure cook dal with 2 cups of ...
# Idli Sambhar  1. Rinse and pressure cook dal with 2 cups of ...
#
# ...

# %%
data_cleaned.reset_index(inplace=True)

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                    clean_ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# 1  Mutton   cubed 500 grams\nOnion\nSalt   to tas...
#
# ...

# %% [markdown]
# # Appending: concat()

# %%
# Append a new recipe
new_recipe = pd.DataFrame({
    'Meal': ['Snack'],
    'Type': ['Vegetarian'],
    'Cuisine': ['Fusion'],
    'Prep_Time': ['5 minutes'],
    'Ingredients': ['Potato, Cheese'],
    'Instructions': ['Mash potatoes, add cheese, fry.'],
    'clean_ingredients': ['Potato, Cheese'],
    'Image_url': [None],
    "Recipe Name":'Quick Cheesy Bites'
})

# Appending: concat()

# Purpose: Appends rows of another DataFrame.
# Example: Add a new recipe to the dataset.
# Industry Use Case: Combining data from different sources.

# %%
data_cleaned.tail(2)
# Out:
#        Recipe Name              Meal  \
# 5155  Idli Sambhar  Breakfast/Snacks
# 5156     Veg Kurma  Breakfast/Snacks
#
#                                                   Links        Type  \
# 5155  https://www.indianhealthyrecipes.com/idli-samb...  Vegetarian
# 5156  https://www.indianhealthyrecipes.com/veg-kurma...  Vegetarian
#
#          Cuisine      Prep_Time  \
# 5155  Hyderabadi  21-25 minutes
# 5156  Tamil Nadu  16-20 minutes
#
#                                             Ingredients  \
# 5155  ['dal', 'dal', 'tamarind', 'Salt', 'shallots o...
# 5156  ['coconut seeds coconut milk', 'cashew nuts', ...
#
#                                            Instructions  \
# 5155  1. Rinse and pressure cook dal with 2 cups of ...
# 5156  1. Fine chop onions & tomatoes. Slit chilli an...
#
#                                       clean_ingredients  \
# 5155  ¾ cup dal (lentils) (refer notes)\n2 cups wate...
# 5156  ¼ cup fresh coconut or 2 tbsps poppy seeds or ...
#
# ...

# %%
new_recipe
# Out:
#     Meal        Type Cuisine  Prep_Time     Ingredients  \
# 0  Snack  Vegetarian  Fusion  5 minutes  Potato, Cheese
#
#                       Instructions clean_ingredients Image_url  \
# 0  Mash potatoes, add cheese, fry.    Potato, Cheese      None
#
#           Recipe Name
# 0  Quick Cheesy Bites

# %%
data_updated = pd.concat([data_cleaned, new_recipe])

# %%
data_updated.tail(2)
# Out:
#              Recipe Name              Meal  \
# 5156           Veg Kurma  Breakfast/Snacks
# 0     Quick Cheesy Bites             Snack
#
#                                                   Links        Type  \
# 5156  https://www.indianhealthyrecipes.com/veg-kurma...  Vegetarian
# 0                                                   NaN  Vegetarian
#
#          Cuisine      Prep_Time  \
# 5156  Tamil Nadu  16-20 minutes
# 0         Fusion      5 minutes
#
#                                             Ingredients  \
# 5156  ['coconut seeds coconut milk', 'cashew nuts', ...
# 0                                        Potato, Cheese
#
#                                            Instructions  \
# 5156  1. Fine chop onions & tomatoes. Slit chilli an...
# 0                       Mash potatoes, add cheese, fry.
#
#                                       clean_ingredients  \
# 5156  ¼ cup fresh coconut or 2 tbsps poppy seeds or ...
# 0                                        Potato, Cheese
#
# ...

# %% [markdown]
# # Handling Duplicates: duplicated(), drop_duplicates()

# %%
# Create a dummy dataset
dummy_data = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5, 5, 6, 7, 8, 8, 9],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Eve', 'Frank', 'Grace', 'Hank', 'Hank', 'Ivy'],
    'Age': [25, 30, 35, 40, 22, 22, 27, 33, 29, 29, 26],
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Kolkata', 'Pune', 'Pune', 'Chennai', 'Hyderabad', 'Jaipur', 'Jaipur', 'Lucknow']
})
dummy_data
# Out:
#     ID     Name  Age       City
# 0    1    Alice   25     Mumbai
# 1    2      Bob   30      Delhi
# 2    3  Charlie   35  Bangalore
# 3    4    David   40    Kolkata
# 4    5      Eve   22       Pune
# 5    5      Eve   22       Pune
# 6    6    Frank   27    Chennai
# 7    7    Grace   33  Hyderabad
# 8    8     Hank   29     Jaipur
# 9    8     Hank   29     Jaipur
# 10   9      Ivy   26    Lucknow

# %%
dummy_data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# dtype: bool

# %%
dummy_data.drop_duplicates()
# Out:
#     ID     Name  Age       City
# 0    1    Alice   25     Mumbai
# 1    2      Bob   30      Delhi
# 2    3  Charlie   35  Bangalore
# 3    4    David   40    Kolkata
# 4    5      Eve   22       Pune
# 6    6    Frank   27    Chennai
# 7    7    Grace   33  Hyderabad
# 8    8     Hank   29     Jaipur
# 10   9      Ivy   26    Lucknow

# %%
dummy_data.duplicated().sum()
# Out:
# 2

# %%
# Identifying duplicates using duplicated()
duplicate_rows = dummy_data.duplicated()

# Removing duplicates using drop_duplicates()
data_no_duplicates = dummy_data.drop_duplicates()

dummy_data, duplicate_rows, data_no_duplicates

# %%
data_updated.duplicated().sum()
# Out:
# 2029

# %%
data_updated.shape
# Out:
# (5158, 10)

# %%
data_updated.duplicated(subset=['Links']).sum()
# Out:
# 2212

# %%
data_updated.drop_duplicates(subset=['Links'])
# Out:
#                              Recipe Name           Meal  \
# 0                     Imli Chawal Recipe   Lunch/Dinner
# 1             Andhra Mutton Curry Recipe   Lunch/Dinner
# 2                   Andhra Styke Chicken   Lunch/Dinner
# 3                   Andhra Chilli Paneer   Lunch/Dinner
# 4                                Avakkai   Lunch/Dinner
# ...                                  ...            ...
# 3124                Homemade Brown Bread  Bread Recipes
# 3125                Homemade White Bread  Bread Recipes
# 3126  Varias - East Indian Wedding bread  Bread Recipes
# 3127         Fugias - East Indian Fugias  Bread Recipes
# 0                     Quick Cheesy Bites          Snack
#
#                                                   Links            Type  \
# 0     https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1     https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2     https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# ...

# %%
# Handle Duplicates: Drop duplicate 'Links' if any
data_no_duplicates = data_updated.drop_duplicates()

# %%
data_no_duplicates.shape
# Out:
# (3129, 10)

# %%
data_no_duplicates.head()
# Out:
#                   Recipe Name          Meal  \
# 0          Imli Chawal Recipe  Lunch/Dinner
# 1  Andhra Mutton Curry Recipe  Lunch/Dinner
# 2        Andhra Styke Chicken  Lunch/Dinner
# 3        Andhra Chilli Paneer  Lunch/Dinner
# 4                     Avakkai  Lunch/Dinner
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
# 2  https://www.sanjeevkapoor.com/Recipe/Andhra-St...  Non-Vegetarian
# 3  https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...      Vegetarian
# 4  https://www.sanjeevkapoor.com/Recipe/Avakkai-S...      Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
# 2  Andhra Pradesh  21-25 minutes
# 3  Andhra Pradesh  16-20 minutes
# 4  Andhra Pradesh        1-2days
#
#                                          Ingredients  \
# ...

# %%
data_no_duplicates['Prep_Time'].str.extract('(\d+)', expand=False).astype(int)
# Out:
# 0       21
# 1       31
# 2       21
# 3       16
# 4        1
#         ..
# 3124    25
# 3125    25
# 3126    25
# 3127    25
# 0        5
# Name: Prep_Time, Length: 3129, dtype: int64

# %% [markdown]
# # Sorting: sort_values()

# %%
# Sort recipes by Prep Time (processing numerical values for sorting)
data_no_duplicates['Prep Time (min)'] = data_no_duplicates["Prep_Time"].str.extract('(\d+)', expand=False).astype(int)
data_no_duplicates.head(2)
# Out:
# <ipython-input-62-6d8eaed4bcba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_no_duplicates['Prep Time (min)'] = data_no_duplicates["Prep_Time"].str.extract('(\d+)', expand=False).astype(int)
#                   Recipe Name          Meal  \
# 0          Imli Chawal Recipe  Lunch/Dinner
# 1  Andhra Mutton Curry Recipe  Lunch/Dinner
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# ...

# %%
data_no_duplicates.sort_values(by=['Prep Time (min)',"Cuisine"],ascending=[True, True])
# Out:
#                     Recipe Name              Meal  \
# 55              Charmuri Recipe      Lunch/Dinner
# 224       Papdi Nu Raitu Recipe             Raita
# 225              Buffena Recipe  Breakfast/Snacks
# 237       Kakdi Nu Raitu Recipe             Raita
# 254        Dahi Ka Achar Recipe            Pickle
# ...                         ...               ...
# 1092   Ragi Sweet Pongal Recipe           Deserts
# 1115             Ukkarai Recipe  Breakfast/Snacks
# 1147  Beans Paruppu Usli Recipe      Lunch/Dinner
# 1190   Gosht Shahi Korma Recipe      Lunch/Dinner
# 1205          Malai Peda Recipe           Deserts
#
#                                                   Links            Type  \
# 55    https://www.sanjeevkapoor.com/Recipe/Charmuri....      Vegetarian
# 224   https://www.sanjeevkapoor.com/Recipe/Papdi-Nu-...      Vegetarian
# 225   https://www.sanjeevkapoor.com/Recipe/Buffena.html      Vegetarian
# ...

# %%
sorted_data = data_no_duplicates.sort_values(by='Prep Time (min)')

# %%
df_sorted_cuisine = df.sort_values(by=['Type', 'Cuisine'], ascending=[True, True])

# %% [markdown]
# # Unique and Nunique: .unique(), .nunique()

# %%
data['Cuisine'].unique()
# Out:
# array(['Andhra Pradesh', 'Bengali', 'Bihari', 'Gujarati', 'Hyderabadi',
#        'Karnataka', 'Kashmiri', 'Kerala', 'Madhya Pradesh',
#        'Maharashtrian', 'Marwari', 'Rajasthani', 'Sindhi', 'Tamil Nadu',
#        'Uttar Pradesh', 'Mumbai', 'Punjabi', 'Indian', 'East'],
#       dtype=object)

# %%
# Count unique cuisines
data['Cuisine'].nunique()
# Out:
# 19

# %%
# Results
results = {
    "Most Common Cuisines": cuisine_counts.head(),
    "Unique Meal Types": unique_meals,
    "Newly Renamed Columns": data.columns,
    "Recipes with Specific Ingredients (Paneer/Chicken)": filtered_recipes[['Meal', 'Cuisine', 'Prep Time']].head(),
    "Unique Cuisines Count": unique_cuisines_count
}

results

# %% [markdown]
# # String Operations
# Functions: str.lower(), str.upper(), str.contains(), str.replace()

# %%
"gaju".upper()
# Out:
# 'GAJU'

# %%
data.head(2)
# Out:
#            Meal                 Recipe Name  \
# 0  Lunch/Dinner          Imli Chawal Recipe
# 1  Lunch/Dinner  Andhra Mutton Curry Recipe
#
#                                                Links            Type  \
# 0  https://www.sanjeevkapoor.com/Recipe/Imli-Chaw...      Vegetarian
# 1  https://www.sanjeevkapoor.com/Recipe/Andhra-Mu...  Non-Vegetarian
#
#           Cuisine      Prep_Time  \
# 0  Andhra Pradesh  21-25 minutes
# 1  Andhra Pradesh  31-40 minutes
#
#                                          Ingredients  \
# 0  [Tamarind (imli) pulp 4 tablespoons,\nCooked r...
# 1  [Mutton cubed 500 grams,\nOnion,\nSalt to tast...
#
#                                         Instructions  \
# 0  1. Heat oil in a non-stick pan, add mustard se...
# 1  1. Pressure cook mutton pieces with two cups o...
#
#                                    clean_ingredients  \
# 0  Tamarind (imli) pulp  4 tablespoons\nCooked ri...
# 1  Mutton   cubed 500 grams\nOnion\nSalt   to tas...
#
# ...

# %%
# Convert 'Recipe Name' to uppercase
data['Recipe Name'] = data['Recipe Name'].str.upper()
print(data[['Recipe Name']])
# Out:
#                      Recipe Name
# 0             IMLI CHAWAL RECIPE
# 1     ANDHRA MUTTON CURRY RECIPE
# 2           ANDHRA STYKE CHICKEN
# 3           ANDHRA CHILLI PANEER
# 4                        AVAKKAI
# ...                          ...
# 5182                   MEDU VADA
# 5183                     SAMBHAR
# 5184                       RASAM
# 5185                IDLI SAMBHAR
# 5186                   VEG KURMA
#
# [5157 rows x 1 columns]

# %%
data[data['Recipe Name'].str.contains('Paneer', case=False)]
# Out:
#                   Meal                   Recipe Name  \
# 3         Lunch/Dinner          ANDHRA CHILLI PANEER
# 46        Lunch/Dinner          PANEER REZALA RECIPE
# 290       Lunch/Dinner         PANEER NAZAKAT RECIPE
# 321       Lunch/Dinner  PANEER PISTE KA SALAN RECIPE
# 349       Lunch/Dinner   PANEER KOFTA MIRCH DO PYAZA
# ...                ...                           ...
# 5127      Lunch/Dinner                  PANEER CURRY
# 5161      Lunch/Dinner                   ALOO PANEER
# 5165     Bread Recipes                 PANEER KULCHA
# 5171  Breakfast/Snacks                    PANEER FRY
# 5177      Lunch/Dinner             PANEER KALI MIRCH
#
#                                                   Links        Type  \
# 3     https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...  Vegetarian
# 46    https://www.sanjeevkapoor.com/Recipe/Paneer-Re...  Vegetarian
# 290   https://www.sanjeevkapoor.com/Recipe/Paneer-Na...  Vegetarian
# ...

# %%
# Filter recipes containing 'Paneer'
paneer_recipes = data[data['Recipe Name'].str.contains('Paneer', case=False)]
print(paneer_recipes)
# Out:
#                   Meal                   Recipe Name  \
# 3         Lunch/Dinner          ANDHRA CHILLI PANEER
# 46        Lunch/Dinner          PANEER REZALA RECIPE
# 290       Lunch/Dinner         PANEER NAZAKAT RECIPE
# 321       Lunch/Dinner  PANEER PISTE KA SALAN RECIPE
# 349       Lunch/Dinner   PANEER KOFTA MIRCH DO PYAZA
# ...                ...                           ...
# 5127      Lunch/Dinner                  PANEER CURRY
# 5161      Lunch/Dinner                   ALOO PANEER
# 5165     Bread Recipes                 PANEER KULCHA
# 5171  Breakfast/Snacks                    PANEER FRY
# 5177      Lunch/Dinner             PANEER KALI MIRCH
#
#                                                   Links        Type  \
# 3     https://www.sanjeevkapoor.com/Recipe/Andhra-Ch...  Vegetarian
# 46    https://www.sanjeevkapoor.com/Recipe/Paneer-Re...  Vegetarian
# 290   https://www.sanjeevkapoor.com/Recipe/Paneer-Na...  Vegetarian
# ...

# %%
"Gaju Bhaiya".replace("a","b")
# Out:
# 'Gbju Bhbiyb'

# %%
data['Cuisine'].str.replace('Andhra Pradesh', 'AP')
# Out:
# 0               AP
# 1               AP
# 2               AP
# 3               AP
# 4               AP
#            ...
# 5182    Hyderabadi
# 5183    Hyderabadi
# 5184    Hyderabadi
# 5185    Hyderabadi
# 5186    Tamil Nadu
# Name: Cuisine, Length: 5157, dtype: object

# %%
# Replace 'Andhra Pradesh' with 'AP' in 'Cuisine'
data['Cuisine'] = data['Cuisine'].replace('Andhra Pradesh', 'AP')
print(data[['Cuisine']])

# %% [markdown]
# 5. Data Type Conversion
# Function: astype()
# Example 1: Convert Time to Prepare to Integer
#
# Industry Use Case: Prepare data for numeric computations like averages or comparisons.

# %%
# Convert 'Time to Prepare(in min)' to integer
df['Time to Prepare(in min)'] = df['Time to Prepare(in min)'].astype(int)
print(df[['Time to Prepare(in min)']])
